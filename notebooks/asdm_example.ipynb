# %% [markdown]
# # Example usage of rdsolver
#
# (c) 2017 Justin Bois. This work is licensed under a [Creative Commons Attribution License CC-BY 4.0](https://creativecommons.org/licenses/by/4.0/). All code contained herein is licensed under an [MIT license](https://opensource.org/licenses/MIT).

# %% [markdown]
# `rdsolver` solves the following system of PDEs on a 2D Cartesian domain with periodic boundary conditions.
#
# \begin{align}
# \partial_t c_i = D_i(\partial_x^2 + \partial_y^2)c_i + \beta_i + \gamma_i c_i + f_i(c_1, c_2, \ldots, t)\,
# \end{align}
#
# where $i$ denotes chemical species. Note that the terms $\beta_i$, $\gamma_i c_i$, and $f_i(c_1, c_2, \ldots)$ are the chemical reaction terms. They are split between linear ($\beta_i$, $\gamma_i c_i$) and nonlinear terms ($f_i$), though there can be linear terms linear in $c_j, j\ne i$ in $f_i$.
#
# To specify the problem, the user needs to supply:
#
# * The physical dimension of the system, which we will call $\mathbf{L} = (L_x, L_y)$
# * The number of grid points $\mathbf{n} = (n_x, n_y)$
# * The desired time points $t_0, t_1, \ldots$
# * The initial concentration profiles of all species, $\mathbf{c}^0(x, y)$
# * The values of the parameters $D_i$, $\beta_i$, and $\gamma_i$ for each species
# * The function $f_i$ and any parametric arguments that need to be passed to it.
#
# Here, I present an example of how to use `rdsolver`. To learn more about it and installation instructions, see the [README file](https://github.com/justinbois/rdsolver#reaction-diffusion-solver).

# %% [markdown]
# ## Necessary imports
#
# We work with `rdsolver` in a Jupyter notebook (recommended), you need to import `rdsolver` and `bokeh`, being sure to call `bokeh.io.output_notebook()` to enable interactive plotting in the Jupyter notebook. And it's pretty much automatic to import NumPy!

# %%
import numpy as np

import rdsolver as rd

import bokeh.io
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2d89a647-5986-436c-a913-6a53514f86f7">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## The activator-substrate depletion model (ASDM)
#
# The ASDM is a classic system that gives Turing patterns. The dimensionless equations are
#
# \begin{align}
# \partial_t a &= d(\partial_x^2 + \partial_y^2)a + a^2s - a \\[1em]
# \partial_t s &= (\partial_x^2 + \partial_y^2)s + \mu(1 - a^2s).
# \end{align}
#
# Thus, we have
#
# \begin{align}
# D &= (d, 1) \\
# \beta &= (0, \mu) \\
# \gamma &= (-1, 0).
# \end{align}
#
# We start by specifying the easy stuff, the physical size of the system, the number of grid points, and the time points we want. Because this particular system does not have very sharp gradients and we are not using a very large physical space, we do not need many grid points at all. Because `rdsolver` uses spectral methods, we can have very accurate calculations even with few grid points. We will use as 32 $\times$ 32 grid here.

# %%
# Physical size of system
L = (10, 10)

# Number of grid points in x and y (can often be small with spec. meth.)
n = (32, 32)

# Specify times points we want
t = np.linspace(0, 250, 100)

# %% [markdown]
# Now, we need to define our parameters. We'll start with $D$, $\beta$, and $\gamma$, choosing $d = 0.05$ and $\mu = 1.4$.

# %%
d = 0.05
mu = 1.4

D = (d, 1)
beta = (0, mu)
gamma = (-1, 0)

# %% [markdown]
# Now, we need to define our nonlinear function $f$. This function has call signature `f(u, t, *f_args)`. The first argument, `u`, is an array containing the concentrations that can be unpacked as follows `a, s = u`.
#
# Next, the function `f` takes the current time as an input. For the ASDM, and indeed for many R-D applications, the nonlinear chemical dynamics do not explicitly depend on time. Finally, `f_args` is a tuple containing any other arguments the function `f` needs.
#
# The function must return an array the same shape as the input array `u` that gives the nonlinear terms in the dynamics. This is most easily accomplished using the `np.stack()` function.

# %%
def f(u, t, mu):
    """Nonlinear terms for ASDM"""
    a, s = u
    return np.stack((a**2 * s, -mu * a**2 * s))

# %% [markdown]
# We also have to specify the arguments that need to be passed to `f` as a tuple.

# %%
# Specify the arguments that need to be passed to f
f_args = (mu, )

# %% [markdown]
# Now, we need to specify the initial conditions. The initial conditions must be a three-dimensional array of shape $(n_s, n_x, n_y)$, where $n_s$ is the number of chemical species. For convenience, you can specify a homogeneous steady state and use the `rd.initial_condition()` function that will generate an initial condition that is a small perturbation about the specified steady state.

# %%
# Homogenous steady state in activator and substrate to perturb
uniform_conc = (1, 1)

# Generate perturbed initial condition
c0 = rd.initial_condition(uniform_conc=uniform_conc, n=n, L=L)

# Show the shape as a demonstration
c0.shape
# Out:
# (2, 32, 32)

# %% [markdown]
# Now, everything is in place. We just have to solve. We do this by calling the `rd.solve()` function. The arguments are obvious from the call below.

# %%
# Solve the system
c = rd.solve(c0, t, D=D, beta=beta, gamma=gamma, f=f, f_args=f_args, L=L)

# Look at the shape of the solution
c.shape
# Out:
# (2, 32, 32, 100)

# %% [markdown]
# We note that the solution is of the shape $(n_s, n_x, n_y, n_t)$, where $n_t$ is the number of time points we used. This structure is useful to know for slicing out species and time points of interest.
#
# For plotting purposes, it is useful to interpolate the solution to have smooth concentration profiles. This is purely aesthetic; the solver will give a pixelated, but spectrally accurate, solution. We can use the `rd.viz.interpolate_concs()` function to get the interpolated concentration profiles.

# %%
c_interp = rd.viz.interpolate_concs(c)

# %% [markdown]
# Finally, we are ready to display the solution. We use the `rd.viz.display_notebook()` function that will give a picture of the concentration field with a slider for adjusting the time. By default, for multiple species problems, (like the ASDM), up to three species are shown. The cyan channel is the first, magenta the second, and yellow is the third (though it is not present for the ASDM).

# %%
rd.viz.display_notebook(t, c_interp)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4074c08a-b63a-4c68-808d-fc3639537864"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4074c08a-b63a-4c68-808d-fc3639537864");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("f83d7b89-56da-48e7-8233-5ac1152bb621", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4074c08a-b63a-4c68-808d-fc3639537864");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4074c08a-b63a-4c68-808d-fc3639537864' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c90b2770-05ee-47ea-983c-6bec24723bd7":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"c634e78f-49e8-46b6-824f-54122e54790f","type":"Title"},{"attributes":{"plot":{"id":"61df525b-f91f-4dc6-a88b-07ebbeb07679","subtype":"Figure","type":"Plot"}},"id":"df2b00ef-86dc-4f4e-9c4a-a3186b4b735b","type":"SaveTool"},{"attributes":{"plot":{"id":"61df525b-f91f-4dc6-a88b-07ebbeb07679","subtype":"Figure","type":"Plot"}},"id":"1d846443-d918-414c-8a06-1c73a4e85099","type":"ResizeTool"},{"attributes":{},"id":"42e4e669-9882-4c91-a247-90ee9a2eb13f","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":
"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"fa612558-c8e7-48b1-ae13-0b59edc55f23","type":"ImageRGBA"},{"attributes":{},"id":"ead3a1ab-fc70-4adb-b883-4dfd82e3380d","type":"BasicTicker"},{"attributes":{"plot":{"id":"61df525b-f91f-4dc6-a88b-07ebbeb07679","subtype":"Figure","type":"Plot"}},"id":"5f07d18e-ca77-4d38-95dd-7fde904fa157","type":"ResetTool"},{"attributes":{"callback":null,"end":200},"id":"730aac97-4e1c-4563-9e9d-d7f4e492303e","type":"Range1d"},{"attributes":{"plot":{"id":"61df525b-f91f-4dc6-a88b-07ebbeb07679","subtype":"Figure","type":"Plot"}},"id":"bbe3b122-5fac-4f39-a58d-8d31ef075ef0","type":"WheelZoo ...

# %% [markdown]
# If we like, we can look at a single species, in which case the colormap is Viridis.

# %%
rd.viz.display_notebook(t, c_interp[0])
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3631426a-37cc-4a1e-8835-b06aad9ef114"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3631426a-37cc-4a1e-8835-b06aad9ef114");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("a251e4c6-0b52-4b6f-b5e8-00eb02858692", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3631426a-37cc-4a1e-8835-b06aad9ef114");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3631426a-37cc-4a1e-8835-b06aad9ef114' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f66bd691-e8d5-49db-9a51-b81cf3f6b153":{"roots":{"references":[{"attributes":{},"id":"6fc64f63-4954-417c-9afb-1c3146f7dbe9","type":"BasicTicker"},{"attributes":{"color_mapper":{"id":"cf60d06a-4b73-48d6-a4d4-c517e81f797a","type":"LinearColorMapper"},"dh":{"units":"data","value":200},"dw":{"units":"data","value":200},"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"ea69505d-8364-4476-88e7-133384d52f60","type":"Image"},{"attributes":{"callback":null,"end":200},"id":"be40b9d3-8586-4c40-9e96-0d8c613a75a4","type":"Range1d"},{"attributes":{},"id":"b155d0e1-bb54-4085-984f-3761302212c3","type":"ToolEvents"},{"attributes":{"callback":null,"end":200},"id":"b35cc43d-39eb-4a6e-8249-e8dc843adb71","type":"Range1d"},{"attributes":{"data_source":{"id":"e786c553-d9b7-430d-936a-ff460df286a4","type":"ColumnDataSource"},"glyph":{"id":"899a769a-ad3d-417a-82ca-468a11ff5160","type":"Image"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ea69505d-8364-4476-88e7-133384d52f60","type":"Image"},"selection_glyph":null},"id":"2659ac4f-d61a-4f7a-8fac-72189a94ab5e","type":"GlyphRenderer"},{"attributes":{},"id":"3e84ee6a-a50a-40c3-acdf-626bc6c3efa3","type":"LinearScale"},{"attributes":{"below":[{"id":"c09942e3-3c12-4376-9653-4e44447fb24b","type":"LinearAxis"}],"left":[{"id":"e8779e45-43e1-43b7-9d81-a0a758727f73","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"c09942e3-3c12-4376-9653-4e44447fb24b","type":"LinearAxis"},{"id":"bef32377-0c6b-431f-ab4c-31d5986921fe","type":"Grid"},{"id":"e8779e45-43e1-43b7-9d81-a0a758727f73","type":"LinearAxis"},{"id":"4d87c70e-2fbb-427a-8572-9a4363e85a01","type":"Grid"},{"id":"ea7b0b1d-548b-4be3-a33c-078f3ed470ac","type":"BoxAnnotation"},{"id":"2659ac4f-d61a-4f7a-8fac-72189a94ab5e","type":"GlyphRenderer"}],"title":{"id":"0765f2d1-718e-44be-8236-6570296169e7","type":"Title"},"tool_events":{"id":"b155d0e1-bb54-4085-984f-3761302212c3","type":"ToolEvents"},"toolbar":{"id":"07d4e337-de75-44e2-adfd-e06672cafbec","type":"Toolbar"},"x_range":{"id":"b35cc43d-39eb-4a6e-8249-e8dc843adb71","type":"Range1d"},"x_scale":{"id":"3e84ee6a-a50a-40c3-acdf-626bc6c3efa3","type":"LinearScale"},"y_range":{"id":"be40b9d3-8586-4c40-9e96-0d8c613a75a4","type":"Range1d"},"y_scale":{"id":"e22c540c-e5d3-4768-ab14-aca934b57463","type":"LinearScale"}},"id":"c3183061-578c-4e74-ba7c-b1c4fd87009f","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"e22c540c-e5d3-4768-ab14-aca934b57463","type":"LinearScale"},{"attributes":{},"id":"07b331d1-bbd6-4842-8916-557c89587819","type":"BasicTicker"},{"attributes":{"formatter":{"id":"d73b3da2-0f47-4fcd-8dd0-e1e9c734b78b","type":"BasicTickFormatter"},"plot":{"id":"c3183061-578c-4e74-ba7c-b1c4fd87009f","subtype":"Figure","type":"Plot"},"ticker":{"id":"6fc64f63-4954-417c-9afb-1c3146f7dbe9","type":"BasicTicker"}},"id":"e8779e45-43e1-43b7-9d81-a0a758727f73","type":"LinearAxis"},{"attributes":{"plot":{"id":"c3183061-578c-4e74-ba7c-b1c4fd87009f","subtype":"Figure","type":"Plot"},"ticker":{"id":"07b331d1-bbd6-4842-8916-557c89587819","type":"BasicTicker"}},"id":"bef32377-0c6b-431f-ab4c-31d5986921fe","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"0765f2d1-718e-44be-8236-6570296169e7","type":"Title"},{"attributes":{"formatter":{"id":"641c0172-6aca-47b6-8ae8-c225b7ca3eed","type":"BasicTickFormatter"},"plot":{"id":"c3183061-578c-4e74-ba7c-b1c4fd87009f","subtype":"Figure","type":"Plot"},"ticker":{"id":"07b331d1-bbd6-4842-8916-557c89587819","type":"BasicTicker"}},"id":"c09942e3-3c12-4376-9653-4e44447fb24b","type":"LinearAxis"},{"attributes":{"plot":{"id":"c3183061-578c-4e74-ba7c-b1c4fd87009f","subtype":"Figure","type":"Plot"}},"id":"d4093030-752f-4607-8c33-9c128a8bcb82","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"c3183061-578c-4e74-ba7c-b1c4fd87009f","subtype":"Figure","type":"Plot"}},"id":"69329499-5202-48f1-95af-5147ee8e3387","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__nda ...
