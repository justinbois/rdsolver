# %% [markdown]
# # Example usage of rdsolver
#
# (c) 2017 Justin Bois. This work is licensed under a [Creative Commons Attribution License CC-BY 4.0](https://creativecommons.org/licenses/by/4.0/). All code contained herein is licensed under an [MIT license](https://opensource.org/licenses/MIT).

# %% [markdown]
# `rdsolver` solves the following system of PDEs on a 2D Cartesian domain with periodic boundary conditions. The governing equations are
#
# \begin{align}
# \partial_t c_i = D_i(\partial_x^2 + \partial_y^2) c_i + \beta_i + \sum_j\gamma_{ij} c_j + f_i(\mathbf{c}),
# \end{align}
#
# where summation over like indices is not implied; all summation is explicit. The last term represents all nonlinear chemical reactions. The $\beta_i + \gamma_{ij}c_j$ terms are linear chemical dynamics. Note that we assume a diagonal constant diffusion tensor.
#
# To specify the problem, the user needs to supply:
#
# * The physical dimension of the system, which we will call $\mathbf{L} = (L_x, L_y)$
# * The number of grid points $\mathbf{n} = (n_x, n_y)$
# * The desired time points $t_0, t_1, \ldots$
# * The initial concentration profiles of all species, $\mathbf{c}^0(x, y)$
# * The values of the parameters $D_i$, $\beta_i$, and $\gamma_{ij}$.
# * The function $f_i$ and any parametric arguments that need to be passed to it.
#
# Here, I present an example of how to use `rdsolver`. To learn more about it and installation instructions, see the [README file](https://github.com/justinbois/rdsolver#reaction-diffusion-solver).

# %% [markdown]
# ## Necessary imports
#
# We work with `rdsolver` in a Jupyter notebook (recommended), you need to import `rdsolver` and `bokeh`, being sure to call `bokeh.io.output_notebook()` to enable interactive plotting in the Jupyter notebook. And it's pretty much automatic to import NumPy!

# %%
import numpy as np
import numba

import rdsolver as rd

import ipywidgets

import bokeh
import bokeh.io
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e510b9c6-cf5e-483a-80bc-fad423f12cbe">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## The activator-substrate depletion model (ASDM)
#
# The ASDM is a classic system that gives Turing patterns. In its simplest form, the dimensionless equations are
#
# \begin{align}
# \partial_t a &= d(\partial_x^2 + \partial_y^2)a + a^2s - a \\[0.5em]
# \partial_t s &= (\partial_x^2 + \partial_y^2)s + \mu(1 - a^2s).
# \end{align}
#
# Thus, we have
#
# \begin{align}
# D &= (d, 1) \\[0.5em]
# \beta &= (0, \mu) \\[0.5em]
# \gamma &= \begin{pmatrix}
# -1 & 0 \\
# 0 & 0
# \end{pmatrix}.
# \end{align}
#
# We start by specifying the easy stuff, the physical size of the system, the number of grid points, and the time points we want. Because this particular system does not have very sharp gradients and we are not using a very large physical space, we do not need many grid points at all. Because `rdsolver` uses spectral methods, we can have very accurate calculations even with few grid points. We will use as 32 $\times$ 32 grid here.

# %%
# Physical size of system
L = (10, 10)

# Number of grid points in x and y (can often be small with spec. meth.)
n = (32, 32)

# Specify times points we want
t = np.linspace(0, 250, 100)

# %% [markdown]
# Now, we need to define our parameters. We'll start with $D$, $\beta$, and $\gamma$, choosing $d = 0.05$ and $\mu = 1.4$.

# %%
d = 0.05
mu = 1.4

D = (d, 1)
beta = (0, mu)
gamma = np.array([[-1, 0], [0, 0]])

# %% [markdown]
# Now, we need to define our nonlinear function $f$. This function has call signature `f(u, t, *f_args)`. The first argument, `u`, is an array containing the concentrations that can be unpacked as `a, s = u`. Note, however, that unpacking 3D arrays like this is not yet supported in Numba, so you should use the more verbose version below for Numba'd nonlinear functions.
#
# Next, the function `f` takes the current time as an input. For the ASDM, and indeed for many R-D applications, the nonlinear chemical dynamics do not explicitly depend on time. Finally, `f_args` is a tuple containing any other arguments the function `f` needs.
#
# The function must return an array the same shape as the input array `u` that gives the nonlinear terms in the dynamics. This is most easily accomplished using the `np.stack()` function.

# %%
@numba.jit(nopython=True)
def f(u, t, mu):
    """Nonlinear terms for ASDM"""
    a = u[0,:,:]
    s = u[1,:,:]
    return np.stack((a**2 * s, -mu * a**2 * s))

# %% [markdown]
# We also have to specify the arguments that need to be passed to `f` as a tuple.

# %%
# Specify the arguments that need to be passed to f
f_args = (mu, )

# %% [markdown]
# Now, we need to specify the initial conditions. The initial conditions must be a three-dimensional array of shape $(n_s, n_x, n_y)$, where $n_s$ is the number of chemical species. For convenience, you can specify a homogeneous steady state and use the `rd.initial_condition()` function that will generate an initial condition that is a small perturbation about the specified steady state.

# %%
# Homogenous steady state in activator and substrate to perturb
uniform_conc = (1, 1)

# Generate perturbed initial condition
np.random.seed(42)
c0 = rd.initial_condition(uniform_conc=uniform_conc, n=n, L=L)

# Show the shape as a demonstration
c0.shape
# Out:
# (2, 32, 32)

# %% [markdown]
# Now, everything is in place. We just have to solve. We do this by calling the `rd.solve()` function. The arguments are obvious from the call below.

# %%
# Solve the system
c = rd.solve(c0, t, D=D, beta=beta, gamma=gamma, f=f, f_args=f_args, L=L)

# Look at the shape of the solution
c.shape
# Out:
# 100%|██████████| 100/100 [00:12<00:00,  8.03it/s]
# (2, 32, 32, 100)

# %% [markdown]
# We note that the solution is of the shape $(n_s, n_x, n_y, n_t)$, where $n_t$ is the number of time points we used. This structure is useful to know for slicing out species and time points of interest.
#
# For plotting purposes, it is useful to interpolate the solution to have smooth concentration profiles. This is purely aesthetic; the solver will give a pixelated, but spectrally accurate, solution. We can use the `rd.viz.interpolate_concs()` function to get the interpolated concentration profiles.

# %%
c_interp = rd.viz.interpolate_concs(c)

# %% [markdown]
# Finally, we are ready to display the solution. We use the `rd.viz.display_notebook()` function that will give a picture of the concentration field with a slider for adjusting the time. By default, for multiple species problems, (like the ASDM), up to three species are shown. The cyan channel is the first, magenta the second, and yellow is the third (though it is not present for the ASDM).

# %%
rd.viz.display_notebook(t, c_interp)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0570599c-18b2-4e8d-ab1d-a0d523f51338"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("0570599c-18b2-4e8d-ab1d-a0d523f51338");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0570599c-18b2-4e8d-ab1d-a0d523f51338");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0570599c-18b2-4e8d-ab1d-a0d523f51338' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3b45731e-c49c-4260-b938-d2389a88ad18":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"473711bd-43fd-4987-b694-56106db91dcd","type":"Title"},{"attributes":{"overlay":{"id":"bca0673a-f69a-4cd1-8775-fe8b3b45c39a","type":"BoxAnnotation"}},"id":"ecfe7ad8-f029-4ded-b1a8-e8945ba6d63d","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"6d10d4d1-b9c6-4837-9914-055849fcbcd2","subtype":"Figure","type":"Plot"},"ticker":{"id":"c76f0934-a7de-4b11-a368-6324917edce9","type":"BasicTicker"}},"id":"c5185b9d-a15d-4975-86a2-59a406af53e9","type":"Grid"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ffc589b6-eade-498b-9df7-fa75120eced4","type":"PanTool"},{"id":"ecfe7ad8-f029-4ded-b1a8-e8945ba6d63d","type":"BoxZoomTool"},{"id":"6995e833-704a-427b-ad18-5338d6ba2627","type":"WheelZoomTool"},{"id":"521035f1-3c99-4c8e-88a6-e2f356675ef3","type":"SaveTool"},{"id":"ac5d8d1c-50f2-47c8-b623-020c39af3642","type":"ResetTool"}]},"id":"40f8a898-c552-49e1-897f-ffde4e72548d","type":"Toolbar"},{"attributes":{},"id":"4f4a1fdb-683b-40b1-b5db-4377256c7fec","type":"LinearScale"},{"attributes":{"formatter":{"id":"57f77fb8-1957-40fb-8db9-8b5ee15b8169","type":"BasicTickFormatter"},"plot":{"id":"6d10d4d1-b9c6-4837-9914-055849fcbcd2","subtype":"Figure","type":"Plot"},"ticker":{"id":"5aea0579-ecb5-4b01-bda8-012e4e038514","type":"BasicTicker"}},"id":"7a2e0c4d-09fe-4247-a433-4ea3f59d6e6d","type":"LinearAxis"},{"attributes":{},"id":"a68de850-68e1-4de8-8dcc-e9e8228d3189","type":"BasicTickFormatter"},{"attributes":{},"id":"521035f1-3c99-4c8e-88a6-e2f356675ef3","type":"SaveTool"},{"attributes":{"data_source":{"id":"5e80d9da-d247-4b79-9f30-39677b7421c6","type":"ColumnDataSource"},"glyph":{"id":"9c6b43ef-81d6-4c6b-8daf-c3fffca81890","type":"ImageRGBA"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d4284e7f-3456-4070-9a2f-7d7b9e524a99","type":"ImageRGBA"},"selection_glyph":null,"view":{"id":"d6fc277c-1afe-4b37-810e-be8c945e7294","type":"CDSView"}},"id":"177e622e-15f9-4c18-9df0-589299b07317","type":"GlyphRenderer"},{"attributes":{},"id":"c76f0934-a7de-4b11-a368-6324917edce9","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"int32","shape":[200,200]}]}},"id":"5e80d9da-d247-4b79-9f30-39677b7421c6","type":"ColumnDataSource"},{"attributes":{"source":{"id":"5e80d9da-d247-4b79-9f30-39677b7421c6","type":"ColumnDataSource"}},"id":"d6fc277c-1afe-4b37-810e-be8c945e7294","type":"CDSView"},{"attributes":{"dh":{"units":"data","value":200},"dw":{"units":"data","value":200},"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"9c6b43ef-81d6-4c6b-8daf-c3fffca81890","type":"ImageRGBA"},{"attributes":{},"id":"5aea0579-ecb5-4b01-bda8-012e4e038514","type":"BasicTicker"},{"attributes":{"formatter":{"id":"a68de850-68e1-4de8-8dcc-e9e8228d3189","type":"BasicTickFormatter"},"plot":{"id":"6d10d4d1-b9c6-4837-9914-055849fcbcd2","subtype":"Figure","type":"Plot"},"ticker":{"id":"c76f0934-a7de-4b11-a368-6324917edce9","type":"BasicTicker"}},"id":"60cedcd4-f8af-4680-9da1-42d7baf4deec","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"6d10d4d1-b9c6-4837-9914-055849fcbcd2","subtype":"Figure","type":"Plot"},"ticker":{"id":"5aea0579-ecb5-4b01-bda8-012e4e038514","type":"BasicTicker"}},"id":"1d0e4412-c3af-4bdd-a54a-ce1ec5e880dc","type":"Grid"},{"attributes":{"callback":null,"end":200},"id":"3565ec00-55cf-4d28-a890-25dfedba89c2","type":"Range1d"},{"attributes":{"callback":null,"end":200},"id":"2b3942e3-cee0-4593-9f71-bddc5367825b","type":"Range1d"},{"attributes":{},"id":"57f77fb8-1957-40fb-8db9-8b5ee15b8169","type":"BasicTickFormatter"},{"attributes":{},"id":"ac5d8d1c-50f2-47c8-b623-020c39af3642","type":"ResetTool"},{"attributes":{},"id":"6995e833-704a-427b-ad18-5338d6ba2627","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"60cedcd4-f8af-4680-9da1-42d7baf4deec","type":"LinearAxis" ...

# %% [markdown]
# If we like, we can look at a single species, in which case the colormap is Viridis.

# %%
rd.viz.display_notebook(t, c_interp[0])
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ef6aa1d1-bd0a-44e7-86bf-8dd599c6a9b1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("ef6aa1d1-bd0a-44e7-86bf-8dd599c6a9b1");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ef6aa1d1-bd0a-44e7-86bf-8dd599c6a9b1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ef6aa1d1-bd0a-44e7-86bf-8dd599c6a9b1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c397011d-b0b4-4382-88bf-f082df6dcc62":{"roots":{"references":[{"attributes":{},"id":"62b31657-11f8-4f49-9ada-ede33e56332c","type":"LinearScale"},{"attributes":{"source":{"id":"e56190e8-5a82-4cc0-82eb-0b3c183459dd","type":"ColumnDataSource"}},"id":"91ddb9cb-eb11-4ae3-adcd-95f0d9731a0a","type":"CDSView"},{"attributes":{"plot":null,"text":""},"id":"979eddc6-12c7-4739-8ae2-0a0af058e71b","type":"Title"},{"attributes":{},"id":"561a6823-7775-4c30-bfb5-210d22904dfc","type":"LinearScale"},{"attributes":{},"id":"e054bab8-17f8-4015-a2e8-8adc19967aac","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"51d4922f-9c92-4545-9a40-e114a540fc00","type":"BoxAnnotation"}},"id":"4658258e-4acf-495a-a8bf-b1f19e5762f2","type":"BoxZoomTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"babcd39f-3f0a-47d3-beb9-472f9c679f45","type":"PanTool"},{"id":"4658258e-4acf-495a-a8bf-b1f19e5762f2","type":"BoxZoomTool"},{"id":"0060eacf-82e4-49f1-b2b2-378690e46991","type":"WheelZoomTool"},{"id":"d7229c85-34b8-46e4-b76c-8024a093aee9","type":"SaveTool"},{"id":"6a8acfcc-ab2a-4939-82b3-85c0628d3012","type":"ResetTool"}]},"id":"db8b947d-3346-4f62-8001-a76d2e42878e","type":"Toolbar"},{"attributes":{},"id":"babcd39f-3f0a-47d3-beb9-472f9c679f45","type":"PanTool"},{"attributes":{},"id":"d7229c85-34b8-46e4-b76c-8024a093aee9","type":"SaveTool"},{"attributes":{},"id":"6a8acfcc-ab2a-4939-82b3-85c0628d3012","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"51d4922f-9c92-4545-9a40-e114a540fc00","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"d851dfcb-d716-412d-8307-b866e8387f32","type":"LinearAxis"}],"left":[{"id":"ec22a55f-8191-43d8-90fc-0dd5981cec60","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"d851dfcb-d716-412d-8307-b866e8387f32","type":"LinearAxis"},{"id":"87a460f6-9cae-437e-ae84-3c563d1983b7","type":"Grid"},{"id":"ec22a55f-8191-43d8-90fc-0dd5981cec60","type":"LinearAxis"},{"id":"c213349c-24cc-4a68-83c0-8578520c223c","type":"Grid"},{"id":"51d4922f-9c92-4545-9a40-e114a540fc00","type":"BoxAnnotation"},{"id":"0f51cea7-0e75-4152-835b-4e8db89edb2a","type":"GlyphRenderer"}],"title":{"id":"979eddc6-12c7-4739-8ae2-0a0af058e71b","type":"Title"},"toolbar":{"id":"db8b947d-3346-4f62-8001-a76d2e42878e","type":"Toolbar"},"x_range":{"id":"ec51cabe-4484-4f24-86be-b1583d0c4e18","type":"Range1d"},"x_scale":{"id":"561a6823-7775-4c30-bfb5-210d22904dfc","type":"LinearScale"},"y_range":{"id":"f7edebdc-f35b-4e7b-b491-deb80c157af1","type":"Range1d"},"y_scale":{"id":"62b31657-11f8-4f49-9ada-ede33e56332c","type":"LinearScale"}},"id":"173f3d22-a338-42f0-a718-24fc0b2df17a","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"float64","shape":[200,200]}]}},"id":"e56190e8-5a82-4cc0-82eb-0b3c183459dd","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"e56190e8-5a82-4cc0-82eb-0b3c183459dd","type":"ColumnDataSource"},"glyph":{"id":"ec389288-eb63-4b7d-a686-6a64f83f86fe","type":"Image"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5972e28d-e377-4a2b-9508-ce20e9f48664","type":"Image"},"selection_glyph":null,"view":{"id":"91ddb9cb-eb11-4ae3-adcd-95f0d9731a0a","type":"CDSView"}},"id":"0f51cea7-0e75-4152-835b-4e8db89edb2a","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"173f3d22-a338-42f0-a718-24fc0b2df17a","subtype":"Figure","type":"Plot"},"ticker":{"id":"a58d66a0-1a2c-40d2-884c-294c90f4087b","type":"BasicTicker"}},"id":"c213349c-24cc-4a68-83c0-8578520c223c","type":"Grid"},{"attributes":{"color_mapper":{"id":"88905fed-952a-408b-b34a-4c611d5f ...

# %% [markdown]
# ## The full ASDM model
#
# We just solved a more simplified ASDM model, but we may consider a more complicated one, as proposed by Koch and Meinhardt (*Rev. Mod. Phys.*, 1994), in which the autocatalysis reactions can saturate.
#
# \begin{align}
# \partial_t a &= D_a (\partial_x^2 + \partial_y^2)a + \frac{\rho_a a^2 s}{1 + \kappa_a a^2} - \mu_a a + \sigma_a \\[0.5em]
# \partial_t s &= D_s (\partial_x^2 + \partial_y^2)s - \frac{\rho_s a^2 s}{1 + \kappa_a a^2} + \sigma_s
# \end{align}
#
# For convenience, `rdsolver` has a growing set of models that you can pre-load. We can use `rd.models.asdm()` to load in the parameters, as well as the homogeneous steady state, for the more complete ASDM model.

# %%
D, beta, gamma, f, f_args, homo_ss = rd.models.asdm()

# %% [markdown]
# The parameters in the above equations are inputted as keyword arguments, with the defaults set to what was used to generate Fig. 2 in the Koch and Meinhardt paper. The outputted function `f` is JITted for performance.
#
# Note that if we wanted to recapitulate the simpler example we already did, we can call the function with the appropriate kwargs.
#
# ```python
# d = 0.05
# mu = 1.4
# params = {'D_a': d,
#           'D_s': 1,
#           'rho_a': 1,
#           'rho_s': mu,
#           'sigma_a': 0,
#           'sigma_s': mu,
#           'mu_a': 1,
#           'kappa_a': 0}
# D, beta, gamma, f, f_args, homo_ss = rd.models.asdm(**params)
# ```
#
# We already did that one, so we'll do the saturating model now. We'll now define the grid setup and the time points we want.

# %%
n = (32, 32)
L = (50, 50)
t = np.linspace(0, 100000, 100)

# %% [markdown]
# Next, the initial condition, which will be a small perturbation about the steady state.

# %%
np.random.seed(42)
c0 = rd.initial_condition(uniform_conc=homo_ss, n=n, L=L)

# %% [markdown]
# Now we can solve and interpolate....

# %%
c = rd.solve(c0, t, D=D, beta=beta, gamma=gamma, f=f, f_args=f_args, L=L)
c_interp = rd.viz.interpolate_concs(c)
# Out:
# 100%|██████████| 100/100 [00:09<00:00, 12.56it/s]

# %% [markdown]
# And finally, we visualize:

# %%
rd.viz.display_notebook(t, c_interp)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="337bfe3d-f890-46d2-87b9-4f1888f8dc7a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("337bfe3d-f890-46d2-87b9-4f1888f8dc7a");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("337bfe3d-f890-46d2-87b9-4f1888f8dc7a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '337bfe3d-f890-46d2-87b9-4f1888f8dc7a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0c83cae2-e2cb-4218-b59c-03011758d612":{"roots":{"references":[{"attributes":{"formatter":{"id":"d2e41fdc-e9e5-4dde-b896-b7619d8e4822","type":"BasicTickFormatter"},"plot":{"id":"c54b3062-ac53-4b64-ba4f-181d71c65eab","subtype":"Figure","type":"Plot"},"ticker":{"id":"53f3e1ec-e239-49a1-a69e-d6cc1043eded","type":"BasicTicker"}},"id":"26b7d0a1-9e64-4e3f-bdd4-6843080e506c","type":"LinearAxis"},{"attributes":{},"id":"5bc5f97f-6a2a-4819-af85-51670b47747f","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"df184f71-cc8c-4519-b401-9126565e59a0","type":"Title"},{"attributes":{},"id":"b7ffab60-6854-4eed-a752-bf8cfa5ad1fb","type":"LinearScale"},{"attributes":{"data_source":{"id":"c2055854-e3a7-49c9-8601-b34e9ba2ce59","type":"ColumnDataSource"},"glyph":{"id":"73bce94e-2259-479b-8a26-19e0a3a55468","type":"ImageRGBA"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"82b743e2-7cf6-469b-9a56-9778cd1442b9","type":"ImageRGBA"},"selection_glyph":null,"view":{"id":"3eb2c9bb-7819-4609-a520-54765e68cea5","type":"CDSView"}},"id":"9ae9dc1e-e93e-42ca-b6fb-bf169e27b10e","type":"GlyphRenderer"},{"attributes":{},"id":"0f94d628-e061-4588-b431-c6a906d12b62","type":"BasicTicker"},{"attributes":{"source":{"id":"c2055854-e3a7-49c9-8601-b34e9ba2ce59","type":"ColumnDataSource"}},"id":"3eb2c9bb-7819-4609-a520-54765e68cea5","type":"CDSView"},{"attributes":{},"id":"d1a69622-7f29-43b3-863d-294f1a3eab54","type":"ResetTool"},{"attributes":{"callback":null,"end":200},"id":"6ca9e8d4-1308-408f-a2b6-d898222e9207","type":"Range1d"},{"attributes":{},"id":"53f3e1ec-e239-49a1-a69e-d6cc1043eded","type":"BasicTicker"},{"attributes":{"below":[{"id":"26b7d0a1-9e64-4e3f-bdd4-6843080e506c","type":"LinearAxis"}],"left":[{"id":"a58aff06-deb4-4338-bfa6-309b3a9335ba","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"26b7d0a1-9e64-4e3f-bdd4-6843080e506c","type":"LinearAxis"},{"id":"53db5eba-ff03-44dc-a2b3-765334a51fb1","type":"Grid"},{"id":"a58aff06-deb4-4338-bfa6-309b3a9335ba","type":"LinearAxis"},{"id":"0d19cc30-7072-42b8-bea2-b3f880fab38c","type":"Grid"},{"id":"a99fb7b4-75fc-43bd-a081-ab03a0a687c1","type":"BoxAnnotation"},{"id":"9ae9dc1e-e93e-42ca-b6fb-bf169e27b10e","type":"GlyphRenderer"}],"title":{"id":"df184f71-cc8c-4519-b401-9126565e59a0","type":"Title"},"toolbar":{"id":"5e548c24-dcb4-41b2-9aea-73d5415bd563","type":"Toolbar"},"x_range":{"id":"b73c516e-2c04-45da-b2b0-f0fe30af71c1","type":"Range1d"},"x_scale":{"id":"b6e3f915-fe5e-4192-ace0-7fcedde0711d","type":"LinearScale"},"y_range":{"id":"6ca9e8d4-1308-408f-a2b6-d898222e9207","type":"Range1d"},"y_scale":{"id":"b7ffab60-6854-4eed-a752-bf8cfa5ad1fb","type":"LinearScale"}},"id":"c54b3062-ac53-4b64-ba4f-181d71c65eab","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"143d6170-8457-4337-a0d9-813b17ed07cb","type":"PanTool"},{"attributes":{},"id":"6db6a5d2-2304-4f7b-b90b-8f6134d41807","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"int32","shape":[200,200]}]}},"id":"c2055854-e3a7-49c9-8601-b34e9ba2ce59","type":"ColumnDataSource"},{"attributes":{"dh":{"units":"data","value":200},"dw":{"units":"data","value":200},"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"73bce94e-2259-479b-8a26-19e0a3a55468","type":"ImageRGBA"},{"attributes":{"formatter":{"id":"5bc5f97f-6a2a-4819-af85-51670b47747f","type":"BasicTickFormatter"},"plot":{"id":"c54b3062-ac53-4b64-ba4f-181d71c65eab","subtype":"Figure","type":"Plot"},"ticker":{"id":"0f94d628-e061-4588-b431-c6a906d12b62","type":"BasicTicker"}},"id":"a58aff06-deb4-4338-bfa6-309b3a9335ba","type":"LinearAxis"},{"attributes":{},"id":"b6e3f915-fe5e-4192-ace0-7fcedde0711d","type":"LinearScale"},{"attributes":{"plot":{"id":"c54b3062-ac53-4b64-ba4f-181d71c65eab","subtype":"Figure","type":"Plot"},"ticker":{"id":"53f3e1ec-e239-49a1-a69e-d6cc1043eded","type":"BasicTicker"}},"id":"53db5eba-ff03-44dc-a2b3-765334a51fb1","type":"Gr ...
