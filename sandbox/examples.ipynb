# %% [markdown]
# # Example usage of rdsolver
#
# (c) 2017 Justin Bois. This work is licensed under a [Creative Commons Attribution License CC-BY 4.0](https://creativecommons.org/licenses/by/4.0/). All code contained herein is licensed under an [MIT license](https://opensource.org/licenses/MIT).

# %% [markdown]
# `rdsolver` solves the following system of PDEs on a 2D Cartesian domain with periodic boundary conditions.
#
# \begin{align}
# \partial_t c_i = D_i(\partial_x^2 + \partial_y^2)c_i + \beta_i + \gamma_i c_i + f_i(c_1, c_2, \ldots, t)\,
# \end{align}
#
# where $i$ denotes chemical species. Note that the terms $\beta_i$, $\gamma_i c_i$, and $f_i(c_1, c_2, \ldots)$ are the chemical reaction terms. They are split between linear ($\beta_i$, $\gamma_i c_i$) and nonlinear terms ($f_i$), though there can be linear terms linear in $c_j, j\ne i$ in $f_i$.
#
# To specify the problem, the user needs to supply:
#
# * The physical dimension of the system, which we will call $\mathbf{L} = (L_x, L_y)$
# * The number of grid points $\mathbf{n} = (n_x, n_y)$
# * The desired time points $t_0, t_1, \ldots$
# * The initial concentration profiles of all species, $\mathbf{c}^0(x, y)$
# * The values of the parameters $D_i$, $\beta_i$, and $\gamma_i$ for each species
# * The function $f_i$ and any parametric arguments that need to be passed to it.
#
# Here, I present an example of how to use `rdsolver`. To learn more about it and installation instructions, see the [README file](https://github.com/justinbois/rdsolver#reaction-diffusion-solver).

# %% [markdown]
# ## Necessary imports
#
# We work with `rdsolver` in a Jupyter notebook (recommended), you need to import `rdsolver` and `bokeh`, being sure to call `bokeh.io.output_notebook()` to enable interactive plotting in the Jupyter notebook. And it's pretty much automatic to import NumPy!

# %%
import numpy as np

import rdsolver as rd

import bokeh.io
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="659888e9-9598-45d3-9347-4687215c1220">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Example 1: The activator-substrate depletion model (ASDM)
#
# For our first example, we will use the ASDM, a classic system that gives Turing patterns. The dimensionless equations are
#
# \begin{align}
# \partial_t a &= d(\partial_x^2 + \partial_y^2)a + a^2s - a \\[1em]
# \partial_t s &= (\partial_x^2 + \partial_y^2)s + \mu(1 - a^2s).
# \end{align}
#
# Thus, we have
#
# \begin{align}
# D &= (d, 1) \\
# \beta &= (0, \mu) \\
# \gamma &= (-1, 0).
# \end{align}
#
# We start by specifying the easy stuff, the physical size of the system, the number of grid points, and the time points we want. Because this particular system does not have very sharp gradients and we are not using a very large physical space, we do not need many grid points at all. Because `rdsolver` uses spectral methods, we can have very accurate calculations even with few grid points. We will use as 32 $\times$ 32 grid here.

# %%
# Physical size of system
L = (10, 10)

# Number of grid points in x and y (can often be small with spec. meth.)
n = (32, 32)

# Specify times points we want
t = np.linspace(0, 250, 100)

# %% [markdown]
# Now, we need to define our parameters. We'll start with $D$, $\beta$, and $\gamma$, choosing $d = 0.05$ and $\mu = 1.4$.

# %%
d = 0.05
mu = 1.4

D = (d, 1)
beta = (0, mu)
gamma = (-1, 0)

# %% [markdown]
# Now, we need to define our nonlinear function $f$. This function has call signature `f(u, t, *f_args)`. The first argument, `u`, is an array containing the concentrations that can be unpacked as follows `a, s = u`.
#
# Next, the function `f` takes the current time as an input. For the ASDM, and indeed for many R-D applications, the nonlinear chemical dynamics do not explicitly depend on time. Finally, `f_args` is a tuple containing any other arguments the function `f` needs.
#
# The function must return an array the same shape as the input array `u` that gives the nonlinear terms in the dynamics. This is most easily accomplished using the `np.stack()` function.

# %%
def f(u, t, mu):
    """Nonlinear terms for ASDM"""
    a, s = u
    return np.stack((a**2 * s, -mu * a**2 * s))

# %% [markdown]
# We also have to specify the arguments that need to be passed to `f` as a tuple.

# %%
# Specify the arguments that need to be passed to f
f_args = (mu, )

# %% [markdown]
# Now, we need to specify the initial conditions. The initial conditions must be a three-dimensional array of shape $(n_s, n_x, n_y)$, where $n_s$ is the number of chemical species. For convenience, you can specify a homogeneous steady state and use the `rd.initial_condition()` function that will generate an initial condition that is a small perturbation about the specified steady state.

# %%
# Homogenous steady state in activator and substrate to perturb
uniform_conc = (1, 1)

# Generate perturbed initial condition
c0 = rd.initial_condition(uniform_conc=uniform_conc, n=n, L=L)

# Show the shape as a demonstration
c0.shape
# Out:
# (2, 32, 32)

# %% [markdown]
# Now, everything is in place. We just have to solve. We do this by calling the `rd.solve()` function. The arguments are obvious from the call below.

# %%
# Solve the system
c = rd.solve(c0, t, D=D, beta=beta, gamma=gamma, f=f, f_args=f_args, L=L)

# Look at the shape of the solution
c.shape
# Out:
# (2, 32, 32, 100)

# %% [markdown]
# We note that the solution is of the shape $(n_s, n_x, n_y, n_t)$, where $n_t$ is the number of time points we used. This structure is useful to know for slicing out species and time points of interest.
#
# For plotting purposes, it is useful to interpolate the solution to have smooth concentration profiles. This is purely aesthetic; the solver will give a pixelated, but spectrally accurate, solution. We can use the `rd.viz.interpolate_concs()` function to get the interpolated concentration profiles.

# %%
c_interp = rd.viz.interpolate_concs(c)

# %% [markdown]
# Finally, we are ready to display the solution. We use the `rd.viz.display_notebook()` function that will give a picture of the concentration field with a slider for adjusting the time. By default, for multiple species problems, (like the ASDM), up to three species are shown. The cyan channel is the first, magenta the second, and yellow is the third (though it is not present for the ASDM).

# %%
rd.viz.display_notebook(t, c_interp)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="082e536a-30f2-4419-ba0e-139d27897f6f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("082e536a-30f2-4419-ba0e-139d27897f6f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("020010c2-725e-4743-8bbb-c212c665bf03", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("082e536a-30f2-4419-ba0e-139d27897f6f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '082e536a-30f2-4419-ba0e-139d27897f6f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4c7f51c1-ac64-4dc7-8fb8-8a76f22b1c9b":{"roots":{"references":[{"attributes":{},"id":"62ee96fd-a872-4ebb-a412-86fbca90925e","type":"ToolEvents"},{"attributes":{"plot":null,"text":""},"id":"81d568b4-e6dd-4149-a4a7-f1c0d63c5c7b","type":"Title"},{"attributes":{},"id":"677463a8-9bff-40c3-aafe-4492e39d6719","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"3b9b6fba-98db-4fdb-9167-c5a8c1dd99ed","type":"ColumnDataSource"},"glyph":{"id":"72510125-2a60-45ed-b51e-9cce75321871","type":"ImageRGBA"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ac46c7b6-c84f-4cf3-8e2c-d6c09acf2333","type":"ImageRGBA"},"selection_glyph":null},"id":"bd00b465-0604-49d9-9cbe-bb5b796b9e5f","type":"GlyphRenderer"},{"attributes":{},"id":"905b4f96-82a6-4bed-93ed-c859b4944bf8","type":"LinearScale"},{"attributes":{"plot":{"id":"b4df3fee-a409-4186-aa60-7435a74005c4","subtype":"Figure","type":"Plot"}},"id":"075f6afd-f9f9-4e44-bdef-3e5310cb52e3","type":"ResetTool"},{"attributes":{"dh":{"units":"data","value":200},"dw":{"units":"data","value":200},"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"ac46c7b6-c84f-4cf3-8e2c-d6c09acf2333","type":"ImageRGBA"},{"attributes":{"formatter":{"id":"677463a8-9bff-40c3-aafe-4492e39d6719","type":"BasicTickFormatter"},"plot":{"id":"b4df3fee-a409-4186-aa60-7435a74005c4","subtype":"Figure","type":"Plot"},"ticker":{"id":"5ce9097d-6b48-4541-96f2-85022999e7c1","type":"BasicTicker"}},"id":"c0e1d9c4-45c8-412e-8f1b-a18a78a2238a","type":"LinearAxis"},{"attributes":{"overlay":{"id":"695bcc4e-0ff9-4091-acb8-954803666528","type":"BoxAnnotation"},"plot":{"id":"b4df3fee-a409-4186-aa60-7435a74005c4","subtype":"Figure","type":"Plot"}},"id":"cf689baa-6288-4d9c-b31e-e0394ae9ed89","type":"BoxZoomTool"},{"attributes":{},"id":"58b37704-efcc-4a4c-9e04-326bed6f9b4c","type":"LinearScale"},{"attributes":{"plot":{"id":"b4df3fee-a409-4186-aa60-7435a74005c4","subtype":"Figure","type":"Plot"},"ticker":{"id":"5ce9097d-6b48-4541-96f2-85022999e7c1","type":"BasicTicker"}},"id":"d6760df5-4441-41f8-a8ff-de978e6823f8","type":"Grid"},{"attributes":{"plot":{"id":"b4df3fee-a409-4186-aa60-7435a74005c4","subtype":"Figure","type":"Plot"}},"id":"e2f22faa-c67e-4e36-87bc-35158c87e35b","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"695bcc4e-0ff9-4091-acb8-954803666528","type":"BoxAnnotation"},{"attributes":{},"id":"5ce9097d-6b48-4541-96f2-85022999e7c1","type":"BasicTicker"},{"attributes":{"callback":null,"end":200},"id":"e9d003d5-6041-405a-91e4-c63c9c9e99e1","type":"Range1d"},{"attributes":{"formatter":{"id":"17a9c153-c63c-4143-9a4b-35f8bd043ab2","type":"BasicTickFormatter"},"plot":{"id":"b4df3fee-a409-4186-aa60-7435a74005c4","subtype":"Figure","type":"Plot"},"ticker":{"id":"a615e982-a941-4590-9e74-5526de6de560","type":"BasicTicker"}},"id":"12c5b7d7-b1e7-4c29-b182-a7a22f8dcdc5","type":"LinearAxis"},{"attributes":{"callback":null,"end":200},"id":"9432ded3-64b5-44d0-a89b-9ee021c4371c","type":"Range1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e2f22faa-c67e-4e36-87bc-35158c87e35b","type":"PanTool"},{"id":"cf689baa-6288-4d9c-b31e-e0394ae9ed89","type":"BoxZoomTool"},{"id":"bde2cc8b-0235-4afd-94cf-490bd9ce52db","type":"WheelZoomTool"},{"id":"8b3b85cd-ef70-4d34-b380-a6bb4cf31da0","type":"SaveTool"},{"id":"075f6afd-f9f9-4e44-bdef-3e5310cb52e3","type":"ResetTool"},{"id":"6c10d2e8-a23f-4ae5-b69b-e78a325644a1","type":"ResizeTool"}]},"id":"3843de24-8a45-4c4e-8ae6-01ae4705e188","type":"Toolbar"},{"attributes":{"plot":{"id":"b4df3fee-a409-4186-aa60-7435a74005c4","subtype":"Figure","type":"Plot"}},"id":"bde2cc8b-0235-4afd-94cf-490bd9ce52db","type":"Wh ...

# %% [markdown]
# If we like, we can look at a single species, in which case the colormap is Viridis.

# %%
rd.viz.display_notebook(t, c_interp[0])
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="23c7388b-7043-4ec6-b37a-d159ac4b70b6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("23c7388b-7043-4ec6-b37a-d159ac4b70b6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("134df64b-8711-4c7a-afa3-974dd90ef462", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("23c7388b-7043-4ec6-b37a-d159ac4b70b6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '23c7388b-7043-4ec6-b37a-d159ac4b70b6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"52fb060d-a16d-45f4-874b-8af68349e867":{"roots":{"references":[{"attributes":{"callback":null,"end":200},"id":"15cc26bf-d3d5-4adb-8d10-c08bba48df6b","type":"Range1d"},{"attributes":{"plot":{"id":"91505350-d8a0-43bf-8841-6d20575b6ba0","subtype":"Figure","type":"Plot"}},"id":"77ed6904-0f1e-4676-b397-2d4384883b06","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"float64","shape":[200,200]}]}},"id":"4b30f744-04b8-4b72-992a-5d74c101f761","type":"ColumnDataSource"},{"attributes":{},"id":"00d52093-65d6-4d9b-86a3-4dee51ffe1c6","type":"LinearScale"},{"attributes":{"callback":null,"end":200},"id":"b37c4565-a8c0-4c4c-8f37-ef7891fc0fea","type":"Range1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"874a7bed-8024-4cdc-8c27-c22381b5a5a1","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"802b0790-6680-45c7-9bee-be2dd7227627","type":"PanTool"},{"id":"c722ce5f-b040-4bf9-83fe-ffc23461dcf8","type":"BoxZoomTool"},{"id":"0d8c95b3-45c3-46b8-bb6e-8108f3ce9beb","type":"WheelZoomTool"},{"id":"8a458db8-6b0e-44a0-873d-08dc598c741a","type":"SaveTool"},{"id":"77ed6904-0f1e-4676-b397-2d4384883b06","type":"ResetTool"},{"id":"8358a603-bb70-443a-a674-1d463086f326","type":"ResizeTool"}]},"id":"1691fe08-9a8e-450a-8ee8-e80c9be6029a","type":"Toolbar"},{"attributes":{"formatter":{"id":"679d17c4-ccb0-491d-9897-e745d8ab4826","type":"BasicTickFormatter"},"plot":{"id":"91505350-d8a0-43bf-8841-6d20575b6ba0","subtype":"Figure","type":"Plot"},"ticker":{"id":"13baa12a-c2cb-4140-9908-4ef811d81c15","type":"BasicTicker"}},"id":"caf01d15-76c9-41e6-85ae-af65c96ca49c","type":"LinearAxis"},{"attributes":{"formatter":{"id":"6fc05a66-e8fa-4834-962b-64241c731a0c","type":"BasicTickFormatter"},"plot":{"id":"91505350-d8a0-43bf-8841-6d20575b6ba0","subtype":"Figure","type":"Plot"},"ticker":{"id":"d51d3883-3654-4d9e-91be-6e696cbb4319","type":"BasicTicker"}},"id":"45d872bb-f7ef-4fe5-9331-92cf26d44857","type":"LinearAxis"},{"attributes":{"color_mapper":{"id":"0497e9b4-a76e-4552-a5e7-2c823219aa37","type":"LinearColorMapper"},"dh":{"units":"data","value":200},"dw":{"units":"data","value":200},"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"a15c2760-b3a6-49bf-92f3-e5a56272e9ec","type":"Image"},{"attributes":{"plot":{"id":"91505350-d8a0-43bf-8841-6d20575b6ba0","subtype":"Figure","type":"Plot"},"ticker":{"id":"d51d3883-3654-4d9e-91be-6e696cbb4319","type":"BasicTicker"}},"id":"e6d9a494-460c-4d42-8c3d-a7b0f7170647","type":"Grid"},{"attributes":{},"id":"b4483610-0c60-44a7-9913-df2eba2d40fc","type":"ToolEvents"},{"attributes":{},"id":"679d17c4-ccb0-491d-9897-e745d8ab4826","type":"BasicTickFormatter"},{"attributes":{},"id":"13baa12a-c2cb-4140-9908-4ef811d81c15","type":"BasicTicker"},{"attributes":{"plot":{"id":"91505350-d8a0-43bf-8841-6d20575b6ba0","subtype":"Figure","type":"Plot"}},"id":"802b0790-6680-45c7-9bee-be2dd7227627","type":"PanTool"},{"attributes":{},"id":"d51d3883-3654-4d9e-91be-6e696cbb4319","type":"BasicTicker"},{"attributes":{"plot":{"id":"91505350-d8a0-43bf-8841-6d20575b6ba0","subtype":"Figure","type":"Plot"}},"id":"0d8c95b3-45c3-46b8-bb6e-8108f3ce9beb","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":""},"id":"0c407424-8dc7-45ba-b7c3-d1a4ddaa1341","type":"Title"},{"attributes":{},"id":"6fc05a66-e8fa-4834-962b-64241c731a0c","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"4b30f744-04b8-4b72-992a-5d74c101f761","type":"ColumnDataSource"},"glyph":{"id":"a144060d-0dfe-4c26-8b8d-2d21095acfb2","type":"Image"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a15c2760 ...

# %% [markdown]
# ## A second example: FitzHugh-Nagumo
#
# For a second example, we consider a model of the FitzHugh-Nagumo type.
#
# \begin{align}
# \partial_t u &= d (\partial_x^2 + \partial_y^2)u - u(u+\alpha)(u-1) - v, \\[1em]
# \partial_t v &= (\partial_x^2 + \partial_y^2)v + (u - v),
# \end{align}
#
# It is useful to expand out the first equation.
#
# \begin{align}
# \partial_t u &= d (\partial_x^2 + \partial_y^2)u - u^3 + (1-\alpha)u^2 + \alpha u - v.
# \end{align}
#
# I will not narrate all the steps here, but set up the problem. We will choose parameters for which no homogeneous steady state exists, and will instead choose an arbitrary initial condition.

# %%
# Grid
L = (20, 20)
n = (128, 128)

# Time points
t = np.linspace(0, 250, 100)

# Parameters
d = 0.15
alpha = 0.04

# Set up D, beta, and gamma
D = (d, 1)
beta = (0, 0)
gamma = (alpha, -1)

# Define nonlinear function
def f(uv, t, alpha):
    """FitzHugh-Nagumo nonlinear terms."""
    u, v = uv
    return np.stack((-u**3 + (1-alpha)*u**2 - v, u))

f_args = (alpha,)

# Starting condition
uniform_conc = (1, 1)
c0 = rd.initial_condition(uniform_conc=uniform_conc, n=n, L=L)

# Solve
c = rd.solve(c0, t, D=D, beta=beta, gamma=gamma, f=f, f_args=f_args, L=L, allow_negative=True)

# %% [markdown]
# Now, we can interpolate and visualize.

# %%
# Interpolate
c_interp = rd.viz.interpolate_concs(c)

# Visualize
rd.viz.display_notebook(t, c_interp)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="55619b25-1b16-451d-8392-92c34cf51b29"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("55619b25-1b16-451d-8392-92c34cf51b29");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("3a3c88f3-3ade-49f4-b964-2a1afb074e8f", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("55619b25-1b16-451d-8392-92c34cf51b29");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '55619b25-1b16-451d-8392-92c34cf51b29' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9e70c0c2-23f6-49d7-aaeb-8883b7b63af2":{"roots":{"references":[{"attributes":{},"id":"ba7ef3c2-a6e0-4ed8-b150-9ac118d58bf8","type":"LinearScale"},{"attributes":{},"id":"02ef39e3-78b0-483e-ac38-900a8036e7e9","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":200},"id":"040817be-8fb0-4f75-aa97-ac4f7ad45a57","type":"Range1d"},{"attributes":{"below":[{"id":"38c47665-4606-4883-8cf3-9b3c2c508182","type":"LinearAxis"}],"left":[{"id":"999dde2f-53a2-45e9-9afe-116c45ed1a4e","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"38c47665-4606-4883-8cf3-9b3c2c508182","type":"LinearAxis"},{"id":"7621e862-51c7-445b-bab9-4b13eb0ab1e9","type":"Grid"},{"id":"999dde2f-53a2-45e9-9afe-116c45ed1a4e","type":"LinearAxis"},{"id":"f2c77240-3f92-40b5-951d-2735cd548ecb","type":"Grid"},{"id":"3a437306-a950-4f79-8820-ee74c3979536","type":"BoxAnnotation"},{"id":"c4cdc8f7-0bbe-4d1b-bce8-1520e5f45499","type":"GlyphRenderer"}],"title":{"id":"720c233c-3cc6-4be2-869e-bcfd05a2a591","type":"Title"},"tool_events":{"id":"f7bcadc3-54f6-47f3-86a9-b4f751407230","type":"ToolEvents"},"toolbar":{"id":"c46fdd2a-7cae-49d9-b280-9d6b51f6eb09","type":"Toolbar"},"x_range":{"id":"040817be-8fb0-4f75-aa97-ac4f7ad45a57","type":"Range1d"},"x_scale":{"id":"24c69f3e-01a3-4fbf-9966-9483bee2a11f","type":"LinearScale"},"y_range":{"id":"5e6ff73a-b8ce-4632-bbe3-fda5d2688138","type":"Range1d"},"y_scale":{"id":"ba7ef3c2-a6e0-4ed8-b150-9ac118d58bf8","type":"LinearScale"}},"id":"c4fa5dc2-c5e3-4061-959b-4e8a51576796","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"f7bcadc3-54f6-47f3-86a9-b4f751407230","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8e55efd7-8b06-4422-813e-81686ccbc204","type":"PanTool"},{"id":"5bf7b03f-d27f-4625-aed7-13104602dd0d","type":"BoxZoomTool"},{"id":"551428b6-0509-45df-b048-c37be13dbdd1","type":"WheelZoomTool"},{"id":"9205be0f-c1df-441d-b8f3-571f0d2f6bcb","type":"SaveTool"},{"id":"5b53d310-4fc9-409b-a041-673e63fb2ccd","type":"ResetTool"},{"id":"372fee42-a480-4c52-a069-b77d6d0c0c20","type":"ResizeTool"}]},"id":"c46fdd2a-7cae-49d9-b280-9d6b51f6eb09","type":"Toolbar"},{"attributes":{"callback":null,"end":200},"id":"5e6ff73a-b8ce-4632-bbe3-fda5d2688138","type":"Range1d"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"int32","shape":[200,200]}]}},"id":"f064506a-7190-4a7e-9b9e-a97268f482ec","type":"ColumnDataSource"},{"attributes":{},"id":"2003dc56-6701-401f-9f08-333f0745093e","type":"BasicTicker"},{"attributes":{"plot":{"id":"c4fa5dc2-c5e3-4061-959b-4e8a51576796","subtype":"Figure","type":"Plot"},"ticker":{"id":"2003dc56-6701-401f-9f08-333f0745093e","type":"BasicTicker"}},"id":"7621e862-51c7-445b-bab9-4b13eb0ab1e9","type":"Grid"},{"attributes":{"formatter":{"id":"02ef39e3-78b0-483e-ac38-900a8036e7e9","type":"BasicTickFormatter"},"plot":{"id":"c4fa5dc2-c5e3-4061-959b-4e8a51576796","subtype":"Figure","type":"Plot"},"ticker":{"id":"2003dc56-6701-401f-9f08-333f0745093e","type":"BasicTicker"}},"id":"38c47665-4606-4883-8cf3-9b3c2c508182","type":"LinearAxis"},{"attributes":{"data_source":{"id":"f064506a-7190-4a7e-9b9e-a97268f482ec","type":"ColumnDataSource"},"glyph":{"id":"d789fca7-426b-448f-848d-5ab4dfd0a916","type":"ImageRGBA"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"17d6160a-1be8-4efc-8b5d-2e3e45370cd5","type":"ImageRGBA"},"selection_glyph":null},"id":"c4cdc8f7-0bbe-4d1b-bce8-1520e5f45499","type":"GlyphRenderer"},{"attributes":{"dh":{"units":"data","value":200},"dw":{"units":"data","value":200},"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"d789fca7-426b-448f-848d-5ab4dfd0a916","type":"ImageRGBA"},{"attributes":{"formatter":{"id":"be165466-83e2-49a3-b873-fba2a9bb6dac","type":"BasicTickFormatter"},"plot":{"id":"c4fa5dc2-c5e3-4061-959b-4e8a51576796","subtype":"Figure","type":"Plot"},"ticker":{"id":"f4045350-0df3-4bcc ...

# %% [markdown]
# ## Min system
#
# The dynamical equations are
#
# \begin{align}
# \partial_t c_\mathrm{D} &= D_\mathrm{D}(\partial_x^2 + \partial_y^2)c_\mathrm{D} + \omega_\mathrm{de} c_\mathrm{de} - \omega_\mathrm{dD}c_\mathrm{d} c_\mathrm{D} - \omega_\mathrm{D}  c_\mathrm{D} \\[0.5em]
# \partial_t c_E &= D_\mathrm{E}(\partial_x^2 + \partial_y^2)c_\mathrm{E} + \omega_\mathrm{de} c_\mathrm{de} - \omega_\mathrm{E} c_\mathrm{d} c_\mathrm{E} - \omega_\mathrm{eE} c_\mathrm{d} c_\mathrm{E} c_\mathrm{de}^2 \\[0.5em]
# \partial_t c_\mathrm{d} &= D_\mathrm{d}(\partial_x^2 + \partial_y^2)c_\mathrm{d} + \omega_\mathrm{D} c_\mathrm{D} + \omega_\mathrm{dD}c_\mathrm{d}c_\mathrm{D} - \omega_\mathrm{E}c_\mathrm{d}c_\mathrm{E} - \omega_\mathrm{eE}c_\mathrm{d}c_\mathrm{E}c_\mathrm{de}^2 \\[0.5em]
# \partial_t c_\mathrm{de} &= D_\mathrm{de}(\partial_x^2 + \partial_y^2)c_\mathrm{de} + \omega_\mathrm{E}c_\mathrm{d}c_\mathrm{E} + \omega_\mathrm{eE}c_\mathrm{d}c_\mathrm{E}c_\mathrm{de}^2 - \omega_\mathrm{de}c_\mathrm{de}.
# \end{align}
